# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Ventas.csv")
df2 = pd.read_csv("Empleadoss.csv")

# %%
df.head()
# Out:
#      IdCliente             NombreCliente     Fecha  Empleado   Referencia  \
# 0  C1070956433                PINTO JOHN  1/9/2016      24.0   LL-2R-0038
# 1  C1032372566                CESAR CRUZ  1/9/2016      14.0  LL-TCA-0133
# 2     C2865810              PINEDA JAIME  1/9/2016      12.0  LL-TCA-0019
# 3    C11210285  VILLALBA RODRIGUEZ FABIO  1/9/2016      24.0  LL-TCA-0009
# 4    C80755314             MOLINA RONALD  1/9/2016      14.0  LL-TCA-0132
#
#               Descripcion  CodigoFamilia Familia  Cantidad    Ventas  \
# 0  PILOT STREET 110/80-17          101.0  LLANTA       1.0  129310.0
# 1       TOURING 175/70R13          101.0  LLANTA       2.0  181034.0
# 2    ENERGY XM2 185/65R14          101.0  LLANTA       1.0  193095.0
# 3    ENERGY XM2 165/65R13          101.0  LLANTA       2.0  262069.0
# 4             NO UTILIZAR          101.0  LLANTA       4.0  362069.0
#
#        Localidad       Sede  Area
# 0  Puente aranda   Calle 13  35.0
# 1           Suba       Suba  32.0
# ...

# %%
df2.head()
# Out:
#    Empleado  Nombre y Apellido
# 0         1       Juan Pastran
# 1         2     Esteban Damico
# 2         3     Julian Quevedo
# 3         4      Oscar Rosseto
# 4         5  Valentin Quintero

# %%
df.dtypes
# Out:
# IdCliente         object
# NombreCliente     object
# Fecha             object
# Empleado         float64
# Referencia        object
# Descripcion       object
# CodigoFamilia    float64
# Familia           object
# Cantidad         float64
# Ventas           float64
# Localidad         object
# Sede              object
# Area             float64
# dtype: object

# %%
df = df.astype({'Area':'string','CodigoFamilia':'string'})

# %%
df
# Out:
#           IdCliente             NombreCliente     Fecha  Empleado  \
# 0       C1070956433                PINTO JOHN  1/9/2016      24.0
# 1       C1032372566                CESAR CRUZ  1/9/2016      14.0
# 2          C2865810              PINEDA JAIME  1/9/2016      12.0
# 3         C11210285  VILLALBA RODRIGUEZ FABIO  1/9/2016      24.0
# 4         C80755314             MOLINA RONALD  1/9/2016      14.0
# ...             ...                       ...       ...       ...
# 127261          NaN                       NaN       NaN       NaN
# 127262          NaN                       NaN       NaN       NaN
# 127263          NaN                       NaN       NaN       NaN
# 127264          NaN                       NaN       NaN       NaN
# 127265          NaN                       NaN       NaN       NaN
#
#          Referencia             Descripcion CodigoFamilia Familia  Cantidad  \
# 0        LL-2R-0038  PILOT STREET 110/80-17         101.0  LLANTA       1.0
# ...

# %%
df.dropna()
# Out:
#           IdCliente                                      NombreCliente  \
# 0       C1070956433                                         PINTO JOHN
# 1       C1032372566                                         CESAR CRUZ
# 2          C2865810                                       PINEDA JAIME
# 3         C11210285                           VILLALBA RODRIGUEZ FABIO
# 4         C80755314                                      MOLINA RONALD
# ...             ...                                                ...
# 127250   C891100881                     MORENO VARGAS SOCIEDAD ANONIMA
# 127251   C900364615                              ORGANIZACION SUMA SAS
# 127252   C900365651  EMPRESA DE TRANSPORTE INTEGRADO DE BOGOTA ETIB...
# 127253   C900365651  EMPRESA DE TRANSPORTE INTEGRADO DE BOGOTA ETIB...
# 127254   C900364615                              ORGANIZACION SUMA SAS
#
#             Fecha  Empleado   Referencia             Descripcion  \
# ...

# %%
df.dtypes
# Out:
# IdCliente         object
# NombreCliente     object
# Fecha             object
# Empleado         float64
# Referencia        object
# Descripcion       object
# CodigoFamilia     string
# Familia           object
# Cantidad         float64
# Ventas           float64
# Localidad         object
# Sede              object
# Area              string
# dtype: object

# %%
df = pd.merge(df, df2, on='Empleado')

# %%
df
# Out:
#           IdCliente                                      NombreCliente  \
# 0       C1070956433                                         PINTO JOHN
# 1         C11210285                           VILLALBA RODRIGUEZ FABIO
# 2         C79827395                                      BALLEN CARLOS
# 3        C900280249                 L&S LOGISTICA Y SUMINISTROS S.A.S.
# 4        C830002366                              BIMBO DE COLOMBIA S.A
# ...             ...                                                ...
# 127250   C900187229  LA IGLESIA DE JESUCRISTO DE LOS SANTOS DE LOS ...
# 127251    C19114850                             FLORES SERRANO ERNESTO
# 127252    C19114850                             FLORES SERRANO ERNESTO
# 127253    C19114850                             FLORES SERRANO ERNESTO
# 127254    C19114850                             FLORES SERRANO ERNESTO
#
#             Fecha  Empleado     Referencia  \
# 0        1/9/2016      24.0     LL-2R-0038
# ...

# %%
df = df.rename(columns={'Empleado':'IdEmpleado','Nombre y Apellido':'Empleado'})

# %%
df = df.astype({'IdEmpleado':'string'})

# %%
df
# Out:
#           IdCliente                                      NombreCliente  \
# 0       C1070956433                                         PINTO JOHN
# 1         C11210285                           VILLALBA RODRIGUEZ FABIO
# 2         C79827395                                      BALLEN CARLOS
# 3        C900280249                 L&S LOGISTICA Y SUMINISTROS S.A.S.
# 4        C830002366                              BIMBO DE COLOMBIA S.A
# ...             ...                                                ...
# 127250   C900187229  LA IGLESIA DE JESUCRISTO DE LOS SANTOS DE LOS ...
# 127251    C19114850                             FLORES SERRANO ERNESTO
# 127252    C19114850                             FLORES SERRANO ERNESTO
# 127253    C19114850                             FLORES SERRANO ERNESTO
# 127254    C19114850                             FLORES SERRANO ERNESTO
#
#             Fecha IdEmpleado     Referencia  \
# 0        1/9/2016       24.0     LL-2R-0038
# ...

# %%
df.dtypes
# Out:
# IdCliente         object
# NombreCliente     object
# Fecha             object
# IdEmpleado        string
# Referencia        object
# Descripcion       object
# CodigoFamilia     string
# Familia           object
# Cantidad         float64
# Ventas           float64
# Localidad         object
# Sede              object
# Area              string
# Empleado          object
# dtype: object

# %%
len(df)
# Out:
# 127255

# %%
df['Familia'].value_counts()
# Out:
# SERVICIOS      88230
# LLANTA         19426
# FILTROS        10291
# LUBRICANTES     4832
# REENCAUCHE      4476
# Name: Familia, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.countplot(data=df,x='Familia',hue='Area').set(title="Ventas por servicio y área");

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.barplot(data=df,x='Sede',y='Ventas',estimator=np.sum,hue="Familia",palette='Set2').set(title='Ventas totales por Sede'); 
plt.legend(bbox_to_anchor=(1,.7));

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.barplot(data=df,x='Sede',y='Ventas',estimator=np.mean,hue="Familia",palette='Set2').set(title='Ventas promedio por Sede'); 
plt.legend(bbox_to_anchor=(1,.7)); #moving the legend box

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.countplot(data=df,x='Sede',hue="Familia").set(title='Numero de ventas por Sede');

# %%
df['Empleado'].value_counts().head() #Los 5 empleados con más cantidad de ventas
# Out:
# Adrian Lucero     22400
# Javier Garay      16357
# Esteban Damico    13719
# Juan Casivar      10261
# Luis Barquiel      8247
# Name: Empleado, dtype: int64

# %%
df['Ventas'].sum() #Total de ventas
# Out:
# 74426081596.0

# %%
df.describe()
# Out:
#             Cantidad        Ventas
# count  127255.000000  1.272550e+05
# mean        2.475872  5.848578e+05
# std        11.206424  3.251382e+06
# min         1.000000  1.300000e+02
# 25%         1.000000  1.260500e+04
# 50%         1.000000  2.941200e+04
# 75%         2.000000  5.172400e+04
# max       971.000000  2.202246e+08

# %%
df.groupby('Empleado').sum().head() #Top empleados con más Ventas
# Out:
#                    Cantidad        Ventas
# Empleado
# Adrian Lucero       33855.0  1.959425e+09
# Adrian Ortiz           13.0  1.966386e+06
# Alejandro Gimenez     254.0  1.162099e+08
# Alejo Alfaro           15.0  1.541510e+05
# BenjamÃ­n Acosta       34.0  5.346696e+06

# %%
plt.figure()
sns.displot(data=df,x='Sede',bins=10).set(title='Numero de Ventas por Sede')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(x="Cantidad",y="Ventas",data=df,hue="Sede",palette="tab10",).set(title="Relación Ventas y Cantidad");

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'], format="%d/%m/%Y")

# %%
df.dtypes
# Out:
# IdCliente                object
# NombreCliente            object
# Fecha            datetime64[ns]
# IdEmpleado               string
# Referencia               object
# Descripcion              object
# CodigoFamilia            string
# Familia                  object
# Cantidad                float64
# Ventas                  float64
# Localidad                object
# Sede                     object
# Area                     string
# Empleado                 object
# dtype: object

# %%
df["Año"] = df["Fecha"].dt.year

# %%
df
# Out:
#           IdCliente                                      NombreCliente  \
# 0       C1070956433                                         PINTO JOHN
# 1         C11210285                           VILLALBA RODRIGUEZ FABIO
# 2         C79827395                                      BALLEN CARLOS
# 3        C900280249                 L&S LOGISTICA Y SUMINISTROS S.A.S.
# 4        C830002366                              BIMBO DE COLOMBIA S.A
# ...             ...                                                ...
# 127250   C900187229  LA IGLESIA DE JESUCRISTO DE LOS SANTOS DE LOS ...
# 127251    C19114850                             FLORES SERRANO ERNESTO
# 127252    C19114850                             FLORES SERRANO ERNESTO
# 127253    C19114850                             FLORES SERRANO ERNESTO
# 127254    C19114850                             FLORES SERRANO ERNESTO
#
#             Fecha IdEmpleado     Referencia  \
# 0      2016-09-01       24.0     LL-2R-0038
# ...

# %%
df.dtypes
# Out:
# IdCliente                object
# NombreCliente            object
# Fecha            datetime64[ns]
# IdEmpleado               string
# Referencia               object
# Descripcion              object
# CodigoFamilia            string
# Familia                  object
# Cantidad                float64
# Ventas                  float64
# Localidad                object
# Sede                     object
# Area                     string
# Empleado                 object
# Año                       int64
# dtype: object

# %%
df['Año'] = pd.to_datetime(df['Año'], format="%Y")

# %%
df
# Out:
#           IdCliente                                      NombreCliente  \
# 0       C1070956433                                         PINTO JOHN
# 1         C11210285                           VILLALBA RODRIGUEZ FABIO
# 2         C79827395                                      BALLEN CARLOS
# 3        C900280249                 L&S LOGISTICA Y SUMINISTROS S.A.S.
# 4        C830002366                              BIMBO DE COLOMBIA S.A
# ...             ...                                                ...
# 127250   C900187229  LA IGLESIA DE JESUCRISTO DE LOS SANTOS DE LOS ...
# 127251    C19114850                             FLORES SERRANO ERNESTO
# 127252    C19114850                             FLORES SERRANO ERNESTO
# 127253    C19114850                             FLORES SERRANO ERNESTO
# 127254    C19114850                             FLORES SERRANO ERNESTO
#
#             Fecha IdEmpleado     Referencia  \
# 0      2016-09-01       24.0     LL-2R-0038
# ...

# %%
sns.lineplot(x='Año',y='Ventas',data=df,hue='Sede',ci=None,markers=["o",".","<","v",">"],style='Familia').set(title="Ventas anuales por sede")
plt.legend(bbox_to_anchor=(1.1,.5))
plt.xticks(rotation=25);

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.lmplot(x="Cantidad",y="Ventas",data=df,palette="tab10",).set(title="Relación Ventas y Cantidad");

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.barplot(data=df,x='Area',y='Ventas',hue="Familia",palette='Set2').set(title='Ventas por Area'); 
plt.legend(bbox_to_anchor=(1,.7));

# %%
sns.lineplot(x='Año',y='Cantidad',data=df,hue='Sede',ci=None).set(title="Numero de Ventas por Sede")
plt.legend(bbox_to_anchor=(1.1,.5))
plt.xticks(rotation=25);

# %%
sns.lineplot(x='Año',y='Ventas',data=df,hue='Sede',ci=None).set(title="Ventas por Sede")
plt.legend(bbox_to_anchor=(1.1,.5))
plt.xticks(rotation=25);

sns.lineplot(x='Año',y='Ventas',data=df,hue='Sede',ci=None,markers=["o",".","<","v",">"],style='Familia').set(title="Ventas anuales por sede")
# Out:
# [Text(0.5, 1.0, 'Ventas anuales por sede')]

# %%
sns.lineplot(x='Año',y='Ventas',data=df,ci=None).set(title="Ventas por año")
plt.xticks(rotation=25);
